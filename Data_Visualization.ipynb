# %% [markdown]
# <a href="https://colab.research.google.com/github/MayureshKadam2001/CODSOFT/blob/main/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df = pd.DataFrame(index=['Ankur', 'Pranav', 'Vivek', 'Raksha', 'Shyam'],
                  data={'Apples':[20, 10, 40, 20, 50],
                        'Oranges':[35, 40, 25, 12, 33]})
df
# Out:
#         Apples  Oranges
# Ankur       20       35
# Pranav      10       40
# Vivek       40       25
# Raksha      20       12
# Shyam       50       33

# %%
df
# Out:
#         Apples  Oranges
# Ankur       20       35
# Pranav      10       40
# Vivek       40       25
# Raksha      20       12
# Shyam       50       33

# %%
df1 = pd.read_csv('/content/df1',index_col = 0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('/content/df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df.plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df2['a'].plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df2['b'].plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df2['c'].plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df.plot(x='Apples', y='Oranges', kind='bar', title='Scatterplot')
# Out:
# <Axes: title={'center': 'Scatterplot'}, xlabel='Apples'>

# %%
df.plot(kind = 'line', title = 'lineplot')
# Out:
# <Axes: title={'center': 'lineplot'}>

# %%
df.plot(kind='bar', title='Bar plot')
# Out:
# <Axes: title={'center': 'Bar plot'}>

# %%
df.plot(kind='kde', figsize=(12,4))
# Out:
# <Axes: ylabel='Density'>

# %%
df
# Out:
#         Apples  Oranges
# Ankur       20       35
# Pranav      10       40
# Vivek       40       25
# Raksha      20       12
# Shyam       50       33

# %%
df.sort_values('Apples').plot(x='Apples', y='Oranges', kind='line')
# Out:
# <Axes: xlabel='Apples'>

# %%
df.plot(x='Apples', kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df.plot.area(alpha=0.7);

# %%
df.plot.barh()
# Out:
# <Axes: >

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot.bar(stacked=True, alpha = 0.9)
# Out:
# <Axes: >

# %%
df.plot.hist(bins=50, alpha=0.6)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot.line(y='B',figsize=(12,3),lw=1)
# Out:
# <Axes: >

# %%
df.plot.scatter(x='Apples',y='Oranges')
# Out:
# <Axes: xlabel='Apples', ylabel='Oranges'>

# %%
df
# Out:
#         Apples  Oranges
# Ankur       20       35
# Pranav      10       40
# Vivek       40       25
# Raksha      20       12
# Shyam       50       33

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x ='A', y = 'B', c = 'C',cmap='RdYlBu')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['Apples', 'Oranges'])
df.plot.hexbin(x='Apples',y='Oranges',gridsize=25,cmap='PuRd')
# Out:
# <Axes: xlabel='Apples', ylabel='Oranges'>

# %%
df2['b'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df1.plot.line(y='B',figsize=(12,3),lw=1)
# Out:
# <Axes: >

# %%
np.random.seed(0)
df = pd.DataFrame({
    'x': np.random.randn(1000),
    'y': np.random.randn(1000)
})


df.plot.hexbin(x='x', y='y', gridsize=20, cmap='coolwarm')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
df
# Out:
#         Apples  Oranges
# Ankur       20       35
# Pranav      10       40
# Vivek       40       25
# Raksha      20       12
# Shyam       50       33

# %%
df.plot.density()
# Out:
# <Axes: ylabel='Density'>
